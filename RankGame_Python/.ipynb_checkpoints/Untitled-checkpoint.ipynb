# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
response = requests.get("https://play.google.com/store/games?device=phone&hl=ko")
response.status_code
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://play.google.com/store/games?device=phone&hl=ko")
html = response.text
soup = BeautifulSoup(html, 'html.parser') # 문자열형태의 html을 태그로 나누어줌
soup.select_one(".OnEJge")
# Out:
# <span class="sT93pb DdYX5 OnEJge">클래시 오브 클랜</span>

# %%
soup.select_one(".OnEJge").text
# Out:
# '클래시 오브 클랜'

# %%
soup.select_one(".OnEJge").attrs
# Out:
# {'class': ['sT93pb', 'DdYX5', 'OnEJge']}

# %%
soup.select_one(".OnEJge").text
# Out:
# '클래시 오브 클랜'

# %%
from bs4 import BeautifulSoup

url = "https://play.google.com/store/games?device=phone&hl=ko"
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

# 'find_all'을 사용하여 원하는 요소를 찾습니다.
games = soup.find_all("span", class_="sT93pb DdYX5 OnEJge")

# 추출된 요소들의 텍스트를 출력합니다.
for game in games:
    print(game.text)
# Out:
# 클래시 오브 클랜
# 꿈의 마을 (Township)
# Free Fire MAX
# Evony: The King's Return
# Klondike Adventures: 농장게임
# 클래시 로얄
# DRAGON BALL LEGENDS 드래곤 볼 레전즈
# 앵그리버드2
# 헝그리 샤크 에볼루션: 최강 상어 먹방 서바이벌 게임
# 로드 모바일:라스트 파이터
# 꿈의 정원 (Gardenscapes)
# 꿈의 집 (Homescapes)
# 모바일 레전드: Bang Bang
# 1945 Air Force: Airplane games
# S.O.S: 스테이트 오브 서바이벌
# Age of Apes: 원숭이 대전
# 아스팔트 9: 레전드
# 벽돌깨기 퀘스트
# 라스트 쉘터: 서바이벌
# 쿠키런: 킹덤
# Mecha Domination: Rampage
# 아우터플레인 (OUTERPLANE)
# Loop Hero
# 브라운더스트2 - 어드벤처 RPG
# 햄스터 여관
# Idle Town Master - Pixel Game
# Amikin Survival
# Guild of Guardians
# 해피 디저트 카페
# 도쿄 디벙커
# Witch's Tale
# 소울웨폰 키우기
# Dragon POW!
# 어설트 릴리 Last Bullet W
# My Stories: Choose Chapters
# 히어로 어셈블: 방치형 액션 RPG
# 카운터사이드
# Dawn of Ages: 중세 게임
# Trails of Cold Steel:NW
# Ikemen Villains Otome Game
# Geometry Tower
# Fishing Frenzy:Idle Hooked Inc
# Wooden Block Jigsaw Puzzle
# 마작 솔리테어 클래식 게임
# Fluffy Ball: Music Hop Game
# Bubble Shooter Magic Adventure
# 드래곤 윙스 - 판타지 슈터
# Sort Match:3D Goods Master
# ...

# %%
import MySQLdb

# %%
# !pip install mysqlclient
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import csv
import MySQLdb  # mysql, mariadb 연동모듈
from datetime import datetime, date

# %%
# mysql(3306) or mariadb(3307) 연결
conn = MySQLdb.connect(host="localhost", port=3306, db='project_db', user='root', password='12345')
print(dir(conn))
print()
# conn.cursor?
cursor = conn.cursor()
print(dir(cursor))
print()

# sql
sql = 'select * from book'
cursor.execute(sql)
suppliers = cursor.fetchall()

for supplier in suppliers:
    output = []
    for i in range(len(supplier)):
        output.append(str(supplier[i]))
    print(output)

cursor.close()
conn.close()
# Out:
# ['DataError', 'DatabaseError', 'Error', 'IntegrityError', 'InterfaceError', 'InternalError', 'NotSupportedError', 'OperationalError', 'ProgrammingError', 'Warning', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_binary_prefix', '_bytes_literal', '_get_native_connection', '_server_version', '_transactional', '_tuple_literal', 'affected_rows', 'autocommit', 'begin', 'change_user', 'character_set_name', 'client_flag', 'close', 'commit', 'converter', 'cursor', 'cursorclass', 'default_cursor', 'discard_result', 'dump_debug_info', 'encoders', 'encoding', 'errno', 'error', 'escape', 'escape_string', 'field_count', 'fileno', 'get_autocommit', 'get_character_
# ...

# %%
import csv
import MySQLdb  # mysql, mariadb 연동모듈
from datetime import datetime
import requests
from bs4 import BeautifulSoup

# 데이터베이스 연결 설정
conn = MySQLdb.connect(host="localhost", port=3306, db='gamelist', user='root', password='12345', charset='utf8')
cursor = conn.cursor()

# 웹 페이지에서 데이터 스크랩
url = "https://play.google.com/store/games?device=phone&hl=ko"
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

# 'find_all'을 사용하여 원하는 요소를 찾습니다.
games = soup.find_all("span", class_="sT93pb DdYX5 OnEJge")

# 데이터베이스에 게임 이름 저장
for game in games:
    game_name = game.text.strip()  # 게임 이름 추출
    query = "INSERT INTO games (name) VALUES (%s)"
    cursor.execute(query, (game_name,))  # 튜플 형태로 매개변수를 전달

# 변경사항을 데이터베이스에 커밋
conn.commit()

# 데이터베이스 연결 종료
cursor.close()
conn.close()

# %%
import MySQLdb
import random

# 데이터베이스 연결 설정
conn = MySQLdb.connect(
    host='localhost',
    user='root',
    password='12345',
    database='gamelist'
)

cursor = conn.cursor()

# 'votes' 열이 있는지 확인하고, 없으면 추가 및 기본값 설정
try:
    cursor.execute("SELECT votes FROM games LIMIT 1;")
except MySQLdb.ProgrammingError:
    cursor.execute("ALTER TABLE games ADD COLUMN votes INT DEFAULT 0;")
    conn.commit()

# 'votes' 열의 기본값을 0으로 수정
cursor.execute("ALTER TABLE games MODIFY COLUMN votes INT DEFAULT 0;")
conn.commit()

# 'votes' 열의 NULL 값을 0으로 업데이트
cursor.execute("UPDATE games SET votes = 0 WHERE votes IS NULL;")
conn.commit()

# 테이블에서 모든 게임 ID를 가져오기
cursor.execute("SELECT id FROM games;")
game_ids = cursor.fetchall()

if not game_ids:
    print("No games found in the database.")
else:
    # 임의의 게임 선택
    random_game_id = random.choice(game_ids)[0]

    # 선택한 게임에 더미 투표 추가
    cursor.execute("UPDATE games SET votes = votes + 1 WHERE id = %s;", (random_game_id,))
    conn.commit()

    # 선택된 게임과 현재 투표 수 출력
    cursor.execute("SELECT name, votes FROM games WHERE id = %s;", (random_game_id,))
    game = cursor.fetchone()
    print(f"Game '{game[0]}' has now {game[1]} votes.")

# 커서 및 연결 닫기
cursor.close()
conn.close()
# Out:
# Game 'Witch's Tale' has now 1 votes.

# %%
import MySQLdb
import random

# 데이터베이스 연결 설정
conn = MySQLdb.connect(
    host='localhost',
    user='root',
    password='12345',
    database='gamelist'
)

cursor = conn.cursor()

# 'votes' 열이 있는지 확인하고, 없으면 추가 및 기본값 설정
try:
    cursor.execute("SELECT votes FROM games LIMIT 1;")
except MySQLdb.ProgrammingError:
    cursor.execute("ALTER TABLE games ADD COLUMN votes INT DEFAULT 0;")
    conn.commit()

# 'votes' 열의 기본값을 0으로 설정
cursor.execute("ALTER TABLE games MODIFY COLUMN votes INT DEFAULT 0;")
conn.commit()

# 모든 게임의 ID 가져오기
cursor.execute("SELECT id FROM games;")
game_ids = cursor.fetchall()

if not game_ids:
    print("No games found in the database.")
else:
    # 각 게임에 대해 10000명의 더미 투표 추가
    for _ in range(10000):
        random_game_id = random.choice(game_ids)[0]
        cursor.execute("UPDATE games SET votes = votes + 1 WHERE id = %s;", (random_game_id,))
        conn.commit()

    print("Dummy votes added for all games.")

    # 각 게임의 이름과 현재 투표 수 출력
    cursor.execute("SELECT name, votes FROM games;")
    games = cursor.fetchall()
    for game in games:
        print(f"Game '{game[0]}' has {game[1]} votes.")

# 커서 및 연결 닫기
cursor.close()
conn.close()
# Out:
# Dummy votes added for all games.
# Game '클래시 오브 클랜' has 128 votes.
# Game '꿈의 마을 (Township)' has 128 votes.
# Game 'Free Fire MAX' has 125 votes.
# Game 'Evony: The King's Return' has 134 votes.
# Game 'Klondike Adventures: 농장게임' has 137 votes.
# Game '클래시 로얄' has 126 votes.
# Game 'DRAGON BALL LEGENDS 드래곤 볼 레전즈' has 129 votes.
# Game '앵그리버드2' has 124 votes.
# Game '헝그리 샤크 에볼루션: 최강 상어 먹방 서바이벌 게임' has 118 votes.
# Game '로드 모바일:라스트 파이터' has 121 votes.
# Game '꿈의 정원 (Gardenscapes)' has 131 votes.
# Game '꿈의 집 (Homescapes)' has 112 votes.
# Game '모바일 레전드: Bang Bang' has 109 votes.
# Game '1945 Air Force: Airplane games' has 130 votes.
# Game 'S.O.S: 스테이트 오브 서바이벌' has 119 votes.
# Game 'Age of Apes: 원숭이 대전' has 118 votes.
# Game '아스팔트 9: 레전드' has 129 votes.
# Game '벽돌깨기 퀘스트' has 126 votes.
# Game '라스트 쉘터: 서바이벌' has 118 votes.
# Game '쿠키런: 킹덤' has 124 votes.
# Game 'Mecha Domination: Rampage' has 109 votes.
# Game '아우터플레인 (OUTERPLANE)' has 119 votes.
# Game 'Loop Hero' has 132 votes.
# ...

# %%
# vote_scheduler.py

import MySQLdb
import random

# 데이터베이스 연결 설정
conn = MySQLdb.connect(
    host='localhost',
    user='root',
    password='12345',
    database='gamelist'
)

cursor = conn.cursor()

# 'votes' 열이 있는지 확인하고, 없으면 추가 및 기본값 설정
try:
    cursor.execute("SELECT votes FROM games LIMIT 1;")
except MySQLdb.ProgrammingError:
    cursor.execute("ALTER TABLE games ADD COLUMN votes INT DEFAULT 0;")
    conn.commit()

# 'votes' 열의 기본값을 0으로 설정
cursor.execute("ALTER TABLE games MODIFY COLUMN votes INT DEFAULT 0;")
conn.commit()

# 모든 게임의 ID 가져오기
cursor.execute("SELECT id FROM games;")
game_ids = cursor.fetchall()

if not game_ids:
    print("No games found in the database.")
else:
    # 각 게임에 대해 10000명의 더미 투표 추가
    for _ in range(10000):
        random_game_id = random.choice(game_ids)[0]
        cursor.execute("UPDATE games SET votes = votes + 1 WHERE id = %s;", (random_game_id,))
        conn.commit()

    print("Dummy votes added for all games.")

    # 각 게임의 이름과 현재 투표 수 출력
    cursor.execute("SELECT name, votes FROM games;")
    games = cursor.fetchall()
    for game in games:
        print(f"Game '{game[0]}' has {game[1]} votes.")

# 커서 및 연결 닫기
cursor.close()
conn.close()
# Out:
# Dummy votes added for all games.
# Game '클래시 오브 클랜' has 252 votes.
# Game '꿈의 마을 (Township)' has 261 votes.
# Game 'Free Fire MAX' has 253 votes.
# Game 'Evony: The King's Return' has 255 votes.
# Game 'Klondike Adventures: 농장게임' has 265 votes.
# Game '클래시 로얄' has 264 votes.
# Game 'DRAGON BALL LEGENDS 드래곤 볼 레전즈' has 244 votes.
# Game '앵그리버드2' has 248 votes.
# Game '헝그리 샤크 에볼루션: 최강 상어 먹방 서바이벌 게임' has 269 votes.
# Game '로드 모바일:라스트 파이터' has 233 votes.
# Game '꿈의 정원 (Gardenscapes)' has 263 votes.
# Game '꿈의 집 (Homescapes)' has 243 votes.
# Game '모바일 레전드: Bang Bang' has 235 votes.
# Game '1945 Air Force: Airplane games' has 275 votes.
# Game 'S.O.S: 스테이트 오브 서바이벌' has 235 votes.
# Game 'Age of Apes: 원숭이 대전' has 254 votes.
# Game '아스팔트 9: 레전드' has 257 votes.
# Game '벽돌깨기 퀘스트' has 270 votes.
# Game '라스트 쉘터: 서바이벌' has 230 votes.
# Game '쿠키런: 킹덤' has 228 votes.
# Game 'Mecha Domination: Rampage' has 230 votes.
# Game '아우터플레인 (OUTERPLANE)' has 252 votes.
# Game 'Loop Hero' has 246 votes.
# ...

# %%
import schedule
import time

from vote_scheduler import add_dummy_votes  # vote_scheduler.py 파일에서 add_dummy_votes 함수 import

# 매 시간마다 add_dummy_votes 함수를 실행하는 스케줄 설정
schedule.every(30).seconds.do(add_dummy_votes)

# 무한 루프에서 스케줄을 실행합니다.
while True:
    schedule.run_pending()
    time.sleep(1)  # CPU 소모를 줄이기 위해 짧은 시간 동안 대기합니다 (선택 사항)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[42], line 4
#       1 import schedule
#       2 import time
# ----> 4 from vote_scheduler import add_dummy_votes  # vote_scheduler.py 파일에서 add_dummy_votes 함수 import
#       6 # 매 시간마다 add_dummy_votes 함수를 실행하는 스케줄 설정
#       7 schedule.every(30).seconds.do(add_dummy_votes)
#
# ImportError: cannot import name 'add_dummy_votes' from 'vote_scheduler' (D:\YooHyunjun\05.python\crolling\vote_scheduler.py)

# %%
import schedule
import time
import MySQLdb
import random

def add_dummy_votes():
    # 데이터베이스 연결 설정
    conn = MySQLdb.connect(
        host='localhost',
        user='root',
        password='12345',
        database='gamelist'
    )

    cursor = conn.cursor()

    # 'votes' 열이 있는지 확인하고, 없으면 추가 및 기본값 설정
    try:
        cursor.execute("SELECT votes FROM games LIMIT 1;")
    except MySQLdb.ProgrammingError:
        cursor.execute("ALTER TABLE games ADD COLUMN votes INT DEFAULT 0;")
        conn.commit()

    # 'votes' 열의 기본값을 0으로 설정
    cursor.execute("ALTER TABLE games MODIFY COLUMN votes INT DEFAULT 0;")
    conn.commit()

    # 모든 게임의 ID 가져오기
    cursor.execute("SELECT id FROM games;")
    game_ids = cursor.fetchall()

    if not game_ids:
        print("No games found in the database.")
    else:
        # 각 게임에 대해 10000명의 더미 투표 추가
        for _ in range(10000):
            random_game_id = random.choice(game_ids)[0]
            cursor.execute("UPDATE games SET votes = votes + 1 WHERE id = %s;", (random_game_id,))
            conn.commit()

        print("Dummy votes added for all games.")

        # 각 게임의 이름과 현재 투표 수 출력
        cursor.execute("SELECT name, votes FROM games;")
        games = cursor.fetchall()
        for game in games:
            print(f"Game '{game[0]}' has {game[1]} votes.")

    # 커서 및 연결 닫기
    cursor.close()
    conn.close()

# 매 30초마다 add_dummy_votes 함수를 실행하는 스케줄 설정
schedule.every(30).seconds.do(add_dummy_votes)

# 무한 루프에서 스케줄을 실행합니다.
while True:
    schedule.run_pending()
    time.sleep(1)  # CPU 소모를 줄이기 위해 짧은 시간 동안 대기합니다 (선택 사항)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[44], line 58
#      56 # 무한 루프에서 스케줄을 실행합니다.
#      57 while True:
# ---> 58     schedule.run_pending()
#      59     time.sleep(1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\schedule\__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\schedule\__init__.py:101, in Scheduler.run_pending(self)
#      99 runnable_jobs = (job for job in self.jobs if job.should_run)
#     100 for job in sorted(runnable_jobs):
# --> 101     self._run_job(job)
#
# ...

# %%
import requests

# 방금 생성한 url
url = "https://api.pubg.com/shards/steam/players?filter[playerNames]=FearNoOne_YILE"
    

header = {
  "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJjZDFhOWE4MC0xZmNlLTAxM2QtZGIzZS0yYWNhNmM1NWIyYzAiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNzIwNDk0NjY0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImdhbWVyYW5rIn0.TwVaNy84Xcmdobi-WZ8OTzptnW2piSW6xak55_I--GM",
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)

# %%
player_dataitgirls_json = r.json()
player_dataitgirls_json
# Out:
# {'data': [{'type': 'player',
#    'id': 'account.38dc994b19884d8da3ef3714ccdddcf0',
#    'attributes': {'name': 'FearNoOne_YILE',
#     'stats': None,
#     'titleId': 'pubg',
#     'shardId': 'steam',
#     'patchVersion': '',
#     'banType': 'Innocent',
#     'clanId': ''},
#    'relationships': {'assets': {'data': []},
#     'matches': {'data': [{'type': 'match',
#        'id': 'affeda1a-68ee-4bfd-960d-bef029b65441'},
#       {'type': 'match', 'id': '6cc0027a-2707-492f-8871-9d60c81f9439'},
#       {'type': 'match', 'id': '3fe6015a-3466-44dc-9992-0754a68a6462'},
#       {'type': 'match', 'id': '7fe2c48c-aad7-46f8-92e6-e10253e8f824'},
#       {'type': 'match', 'id': '6a4ba9b5-8ce9-4c0e-b0d3-4577e5859990'},
#       {'type': 'match', 'id': 'd13c4831-a221-4436-95d0-806f10c1c11b'},
#       {'type': 'match', 'id': '411f5396-7f6e-4ad9-83cd-9f75a409bd34'},
#       {'type': 'match', 'id': '13ea045e-6c5f-4175-b719-fd8edddce54b'},
# ...

# %%
import requests

url = "https://api.pubg.com/shards/steam/players/account.38dc994b19884d8da3ef3714ccdddcf0"

header = {
  "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJjZDFhOWE4MC0xZmNlLTAxM2QtZGIzZS0yYWNhNmM1NWIyYzAiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNzIwNDk0NjY0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImdhbWVyYW5rIn0.TwVaNy84Xcmdobi-WZ8OTzptnW2piSW6xak55_I--GM",
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)

# %%
player_dataitgirls_json = r.json()
player_dataitgirls_json
# Out:
# {'data': {'type': 'player',
#   'id': 'account.38dc994b19884d8da3ef3714ccdddcf0',
#   'attributes': {'titleId': 'pubg',
#    'shardId': 'steam',
#    'patchVersion': '',
#    'banType': 'Innocent',
#    'clanId': '',
#    'name': 'FearNoOne_YILE',
#    'stats': None},
#   'relationships': {'matches': {'data': [{'type': 'match',
#       'id': 'affeda1a-68ee-4bfd-960d-bef029b65441'},
#      {'type': 'match', 'id': '6cc0027a-2707-492f-8871-9d60c81f9439'},
#      {'type': 'match', 'id': '3fe6015a-3466-44dc-9992-0754a68a6462'},
#      {'type': 'match', 'id': '7fe2c48c-aad7-46f8-92e6-e10253e8f824'},
#      {'type': 'match', 'id': '6a4ba9b5-8ce9-4c0e-b0d3-4577e5859990'},
#      {'type': 'match', 'id': 'd13c4831-a221-4436-95d0-806f10c1c11b'},
#      {'type': 'match', 'id': '411f5396-7f6e-4ad9-83cd-9f75a409bd34'},
#      {'type': 'match', 'id': '13ea045e-6c5f-4175-b719-fd8edddce54b'},
#      {'type': 'match', 'id': 'e9b7416b-9a38-4da5-b1d5-b2a9015be339'},
# ...

# %%
import requests

# PUBG API 키
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJjZDFhOWE4MC0xZmNlLTAxM2QtZGIzZS0yYWNhNmM1NWIyYzAiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNzIwNDk0NjY0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImdhbWVyYW5rIn0.TwVaNy84Xcmdobi-WZ8OTzptnW2piSW6xak55_I--GM'
headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept': 'application/vnd.api+json'
}

# 매치 ID
match_id = 'account.38dc994b19884d8da3ef3714ccdddcf0'

# API 요청 URL
url = f'https://api.pubg.com/shards/steam/matches/{match_id}'

# API 요청
response = requests.get(url, headers=headers)

# 응답 데이터 처리
if response.status_code == 200:
    match_data = response.json()
    # 여기서 RP 데이터를 추출
    print(match_data)
else:
    print(f"Error: {response.status_code}")

# RP 데이터는 match_data에서 추출할 수 있습니다.
