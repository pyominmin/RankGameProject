# %%
# <게임 이름 스크래핑>
import csv
import MySQLdb  # mysql, mariadb 연동모듈
from datetime import datetime
import requests
from bs4 import BeautifulSoup

# 데이터베이스 연결 설정
conn = MySQLdb.connect(host="localhost", port=3306, db='gamelist', user='root', password='12345', charset='utf8')
cursor = conn.cursor()

# 웹 페이지에서 데이터 스크랩
url = "https://play.google.com/store/games?device=phone&hl=ko"
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

# 'find_all'을 사용하여 원하는 요소를 찾습니다.
games = soup.find_all("span", class_="sT93pb DdYX5 OnEJge")

# 데이터베이스에 게임 이름 저장
for game in games:
    game_name = game.text.strip()  # 게임 이름 추출
    query = "INSERT INTO games (game_name) VALUES (%s)"
    cursor.execute(query, (game_name,))  # 튜플 형태로 매개변수를 전달

# 변경사항을 데이터베이스에 커밋
conn.commit()

# 데이터베이스 연결 종료
cursor.close()
conn.close()

# %%
# 투표 및 랭킹 DB저장
import requests
from bs4 import BeautifulSoup
import MySQLdb  # MySQL, MariaDB 연동 모듈
import random
import time
import schedule
from datetime import datetime

# 데이터베이스 연결 설정
conn = MySQLdb.connect(host="localhost", port=3306, db='gamelist', user='root', password='12345', charset='utf8')
cursor = conn.cursor()

# 게임 이름 후보자 가져오기
def get_candidates():
    query = "SELECT id, game_name FROM games"
    cursor.execute(query)
    return cursor.fetchall()

# 투표 함수
def cast_vote(candidate_id):
    query = "UPDATE games SET game_vote = game_vote + 1 WHERE id = %s"
    cursor.execute(query, (candidate_id,))

# 현재 투표 결과를 저장하는 함수
def save_current_results():
    timestamp = datetime.now()
    query = """
    SELECT id, game_vote
    FROM games
    ORDER BY game_vote DESC
    """
    cursor.execute(query)
    results = cursor.fetchall()
    
    for rank, (game_id, vote_count) in enumerate(results, 1):
        update_query = """
        UPDATE games SET `game_rank` = %s WHERE id = %s
        """
        cursor.execute(update_query, (rank, game_id))
    
    conn.commit()
    print(f"현재 결과 저장됨: {timestamp}")

# 결과 보기 함수
def show_results():
    query = """
    SELECT game_name, game_vote
    FROM games
    ORDER BY game_vote DESC
    LIMIT 50
    """
    cursor.execute(query)
    results = cursor.fetchall()
    print("\n상위 50개 게임 투표 결과:")
    for idx, result in enumerate(results, 1):
        print(f"{idx}위: {result[0]}: {result[1]} 명 투표")

# 투표 기록 초기화
def reset_votes():
    query = "UPDATE games SET game_vote = 0"
    cursor.execute(query)
    conn.commit()

# 1,000명의 사용자 투표 시뮬레이션
def simulate_voting():
    candidates = get_candidates()
    candidate_ids = [candidate[0] for candidate in candidates]

    for _ in range(1000):
        candidate_id = random.choice(candidate_ids)
        cast_vote(candidate_id)
    
    conn.commit()  # 모든 투표를 한 번에 커밋

# 1분마다 실행되는 작업
def job():
    reset_votes()
    simulate_voting()
    show_results()

# 1분마다 실행되는 작업 (결과 저장)
def daily_job():
    save_current_results()

# 스케줄 설정
# schedule.every(1).minutes.do(job)
# schedule.every(1).minutes.do(daily_job)

schedule.every(10).seconds.do(job)  # 10초마다 job() 함수 실행
schedule.every(10).seconds.do(daily_job)  # 10초마다 daily_job() 함수 실행

# 초기 실행
job()

while True:
    schedule.run_pending()
    time.sleep(1)

# 데이터베이스 연결 종료
cursor.close()
conn.close()
# Out:
# 상위 50개 게임 투표 결과:
# 1위: 1945 Air Force: Airplane games: 21 명 투표
# 2위: Free Fire MAX: 20 명 투표
# 3위: Sort Match:3D Goods Master: 20 명 투표
# 4위: 브롤스타즈: 19 명 투표
# 5위: 꿈의 정원 (Gardenscapes): 19 명 투표
# 6위: 소울웨폰 키우기: 18 명 투표
# 7위: 악마가 되었다: 18 명 투표
# 8위: Mecha Domination: Rampage: 17 명 투표
# 9위: 매직 타일 3: 17 명 투표
# 10위: Kingdom Defense：Magic vs Slime: 17 명 투표
# 11위: Age of Apes: 원숭이 대전: 17 명 투표
# 12위: Fluffy Ball: Music Hop Game: 17 명 투표
# 13위: Among Us: 16 명 투표
# 14위: Dog Shelter: 16 명 투표
# 15위: 마이토킹톰 2: 16 명 투표
# 16위: Hexa Sort: 16 명 투표
# 17위: 도쿄 디벙커: 16 명 투표
# 18위: Coin Master: 16 명 투표
# 19위: Amikin Survival: 15 명 투표
# 20위: Idle Town Master - Pixel Game: 15 명 투표
# 21위: Guild of Guardians: 15 명 투표
# 22위: Dragon POW!: 15 명 투표
# 23위: 클래시 오브 클랜: 15 명 투표
# 24위: Puzzle Legends: 15 명 투표
# 25위: 8 Ball Pool: 14 명 투표
# 26위: 나무 너트 볼트 - 퍼즐 게임: 14 명 투표
# 27위: Subway Surfers: 14 명 투표
# 28위: 아우터플레인 (OUTERPLANE): 14 명 투표
# 29위: Hedgies: Farming & Building: 14 명 투표
# 30위: 브라운더스트2 - 어드벤처 RPG: 14 명 투표
# 31위: Candy Crush Saga: 13 명 투표
# 32위: 아스팔트 9: 레전드: 13 명 투표
# 33위: 라스트 쉘터: 서바이벌: 13 명 투표
# 34위: 어설트 릴리 Last Bullet W: 13 명 투표
# 35위: Block Craft 3D：Building Game: 13 명 투표
# 36위: Bingo Blitz™️ - Bingo Games: 13 명 투표
# 37위: EA SPORTS FC™: UEFA EURO 2024™: 13 명 투표
# 38위: Evony: The King's Return: 12 명 투표
# 39위: 히어로 어셈블: 방치형 액션 RPG: 12 명 투표
# 40위: DRAGON BALL LEGENDS 드래곤 볼 레전즈: 12 명 투표
# 41위: Mini Heroes: Mars' Squad: 12 명 투표
# 42위: 로드 모바일:라스트 파이터: 12 명 투표
# 43위: Dawn of Ages: 중세 게임: 12 명 투표
# 44위: 로얄 매치 Royal Match: 12 명 투표
# 45위: Geometry Tower: 12 명 투표
# 46위: 마작 솔리테어 클래식 게임: 12 명 투표
# 47위: Chaos Galaxy - 우주 사격수: 12 명 투표
# 48위: 햄스터 여관: 12 명 투표
# 49위: 모바일 레전드: Bang Bang: 11 명 투표
# 50위: 벽돌깨기 퀘스트: 11 명 투표
#
# 상위 50개 게임 투표 결과:
# 1위: 나무 너트 볼트 - 퍼즐 게임: 21 명 투표
# 2위: 매직 타일 3: 19 명 투표
# 3위: Call of Duty: Mobile Season 6: 19 명 투표
# 4위: 모바일 레전드: Bang Bang: 17 명 투표
# 5위: Subway Surfers: 17 명 투표
# 6위: Idle Town Master - Pixel Game: 17 명 투표
# 7위: Mini Heroes: Mars' Squad: 17 명 투표
# 8위: 소울웨폰 키우기: 16 명 투표
# 9위: 로얄 매치 Royal Match: 16 명 투표
# 10위: Among Us: 16 명 투표
# 11위: 언더 서바이벌 : 어드벤쳐&시뮬레이션: 16 명 투표
# 12위: 도쿄 디벙커: 15 명 투표
# 13위: Kingdom Defense：Magic vs Slime: 15 명 투표
# 14위: Witch's Tale: 15 명 투표
# 15위: EA SPORTS FC™: UEFA EURO 2024™: 15 명 투표
# 16위: Geometry Dash Lite: 15 명 투표
# 17위: Mecha Domination: Rampage: 15 명 투표
# 18위: 라스트 쉘터: 서바이벌: 15 명 투표
# 19위: Dog Shelter: 15 명 투표
# 20위: Fishing Frenzy:Idle Hooked Inc: 14 명 투표
# 21위: My Stories: Choose Chapters: 14 명 투표
# 22위: Cooking Story: Chef's Journey: 14 명 투표
# 23위: 히어로 어셈블: 방치형 액션 RPG: 14 명 투표
# 24위: Hedgies: Farming & Building: 14 명 투표
# 25위: Chaos Galaxy - 우주 사격수: 14 명 투표
# 26위: Amikin Survival: 14 명 투표
# 27위: Coin Master: 14 명 투표
# 28위: 앵그리버드2: 14 명 투표
# 29위: 카운터사이드: 14 명 투표
# 30위: Terra World: 캐릭터 창조 게임: 14 명 투표
# 31위: 8 Ball Pool: 14 명 투표
# 32위: S.O.S: 스테이트 오브 서바이벌: 14 명 투표
# 33위: 벽돌깨기 퀘스트: 14 명 투표
# 34위: Fluffy Ball: Music Hop Game: 13 명 투표
# 35위: Pokémon GO: 13 명 투표
# 36위: Earn to Die Rogue: 13 명 투표
# 37위: 헝그리 샤크 에볼루션: 최강 상어 먹방 서바이벌 게임: 13 명 투표
# 38위: Loop Hero: 13 명 투표
# 39위: Dragon POW!: 13 명 투표
# 40위: 악마가 되었다: 13 명 투표
# 41위: 클래시 오브 클랜: 13 명 투표
# 42위: 드래곤 윙스 - 판타지 슈터: 12 명 투표
# 43위: Geometry Tower: 12 명 투표
# 44위: 아우터플레인 (OUTERPLANE): 12 명 투표
# 45위: Find Stuff in America: 12 명 투표
# 46위: 1945 Air Force: Airplane games: 12 명 투표
# 47위: 로드 모바일:라스트 파이터: 12 명 투표
# 48위: Candy Crush Saga: 12 명 투표
# 49위: 레이스 마스터 3D (Race Master 3D): 12 명 투표
# 50위: Evony: The King's Return: 11 명 투표
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 97
#      94 job()
#      96 while True:
# ---> 97     schedule.run_pending()
#      98     time.sleep(1)
#     100 # 데이터베이스 연결 종료
#
# File ~\AppData\Roaming\Python\Python311\site-packages\schedule\__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\schedule\__init__.py:101, in Scheduler.run_pending(self)
#      99 runnable_jobs = (job for job in self.jobs if job.should_run)
#     100 for job in sorted(runnable_jobs):
# --> 101     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\schedule\__init__.py:173, in Scheduler._run_job(self, job)
#     172 def _run_job(self, job: "Job") -> None:
# --> 173     ret = job.run()
#     174     if isinstance(ret, CancelJob) or ret is CancelJob:
#     175         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\schedule\__init__.py:691, in Job.run(self)
#     688     return CancelJob
#     690 logger.debug("Running job %s", self)
# --> 691 ret = self.job_func()
#     692 self.last_run = datetime.datetime.now()
#     693 self._schedule_next_run()
#
# Cell In[8], line 84, in daily_job()
#      83 def daily_job():
# ---> 84     save_current_results()
#
# Cell In[11], line 40, in save_current_results()
#      36 for rank, (game_id, vote_count) in enumerate(results, 1):
#      37     update_query = """
#      38     UPDATE games SET `rank` = %s WHERE id = %s
#      39     """
# ---> 40     cursor.execute(update_query, (rank, game_id))
#      42 conn.commit()
#      43 print(f"현재 결과 저장됨: {timestamp}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\MySQLdb\cursors.py:179, in BaseCursor.execute(self, query, args)
#     176 mogrified_query = self._mogrify(query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File ~\AppData\Roaming\Python\Python311\site-packages\MySQLdb\cursors.py:330, in BaseCursor._query(self, q)
#     328 self.rowcount = None
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#     332 self._post_get_result()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\MySQLdb\connections.py:261, in Connection.query(self, query)
#     259 if isinstance(query, bytearray):
#     260     query = bytes(query)
# --> 261 _mysql.connection.query(self, query)
#
# OperationalError: (1054, "Unknown column 'rank' in 'field list'")
